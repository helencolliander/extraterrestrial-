# %% [markdown]
# ## Extraterrestrial Science Fair Log Book

# %% [markdown]
# downloaded anaconda from continium analytics website

# %% [markdown]
# launched ipython notebook with python 3 process

# %% [markdown]
# nasa database of CONFIRMED exoplanets>> examined exoplanet properties, dowloaded table in CSV format to use for analytics in Anaconda. http://exoplanetarchive.ipac.caltech.edu/cgi-bin/TblView/nph-tblView?app=ExoTbls&config=planets

# %% [markdown]
# ## Acessing Data

# %%
2+2
# Out:
# 4

# %%
import pandas as pd

# %%
# %matplotlib inline

# %%
data = pd.read_csv('planets.csv', comment='#')

# %%
data.describe()
# Out:
#              rowid      pl_pnum      pl_orbper  pl_orbpererr1  pl_orbpererr2  \
# count  1937.000000  1937.000000    1874.000000    1744.000000    1744.000000
# mean    969.000000     2.133712    1165.127531     369.370578    -446.293421
# std     559.308055     1.224823   21631.987669    9808.886740   12167.296913
# min       1.000000     1.000000       0.090706       0.000000 -365000.000000
# 25%     485.000000     1.000000       5.492256       0.000022      -0.061750
# 50%     969.000000     2.000000      15.781452       0.000179      -0.000180
# 75%    1453.000000     3.000000     114.128587       0.060750      -0.000022
# max    1937.000000     7.000000  730000.000000  365000.000000       0.000000
#
#        pl_orbperlim   pl_orbsmax  pl_orbsmaxerr1  pl_orbsmaxerr2  \
# count   1873.000000  1758.000000      873.000000      872.000000
# mean      -0.000534     8.098284        0.565329       -0.597691
# std        0.040028    92.966010        7.303683        7.694447
# min       -1.000000     0.004400        0.000000     -200.000000
# 25%        0.000000     0.060702        0.001000       -0.048500
# 50%        0.000000     0.127500        0.005000       -0.005150
# 75%        0.000000     0.708700        0.050000       -0.001000
# max        1.000000  2500.000000      200.000000        0.000000
#
#        pl_orbsmaxlim     ...           st_mass  st_masserr1  st_masserr2  \
# count           1753     ...       1547.000000   981.000000   895.000000
# mean               0     ...          0.989198     0.088807    -0.082458
# std                0     ...          0.370753     0.140311     0.101871
# min                0     ...          0.020000     0.000000    -1.500000
# 25%                0     ...          0.800000     0.040000    -0.100000
# 50%                0     ...          0.980000     0.050000    -0.060000
# 75%                0     ...          1.140000     0.100000    -0.030000
# max                0     ...          3.900000     1.660000     0.000000
#
#         st_masslim  st_massblend       st_rad   st_raderr1   st_raderr2  \
# count  1543.000000          1465  1563.000000  1505.000000  1420.000000
# mean     -0.003889             0     1.825598     0.262073    -0.267423
# std       0.062257             0     4.257170     1.136444     1.172221
# min      -1.000000             0     0.040000     0.000000   -26.000000
# 25%       0.000000             0     0.800000     0.040000    -0.290000
# 50%       0.000000             0     1.020000     0.100000    -0.100000
# 75%       0.000000             0     1.330000     0.290000    -0.040000
# max       0.000000             0    51.100000    26.000000     0.000000
#
#        st_radlim  st_radblend
# count       1562         1663
# mean           0            0
# std            0            0
# min            0            0
# 25%            0            0
# 50%            0            0
# 75%            0            0
# max            0            0
#
# [8 rows x 59 columns]

# %% [markdown]
# ## column meanings
# ```
# # This file was produced by the NASA Exoplanet Archive  http://exoplanetarchive.ipac.caltech.edu
# # Tue Feb  9 20:14:59 2016
# #
# # COLUMN pl_hostname:    Host Name
# # COLUMN pl_letter:      Planet Letter
# # COLUMN pl_discmethod:  Discovery Method
# # COLUMN pl_pnum:        Number of Planets in System
# # COLUMN pl_orbper:      Orbital Period [days]
# # COLUMN pl_orbpererr1:  Orbital Period Upper Unc. [days]
# # COLUMN pl_orbpererr2:  Orbital Period Lower Unc. [days]
# # COLUMN pl_orbperlim:   Orbital Period Limit Flag
# # COLUMN pl_orbsmax:     Orbit Semi-Major Axis [AU]
# # COLUMN pl_orbsmaxerr1: Orbit Semi-Major Axis Upper Unc. [AU]
# # COLUMN pl_orbsmaxerr2: Orbit Semi-Major Axis Lower Unc. [AU]
# # COLUMN pl_orbsmaxlim:  Orbit Semi-Major Axis Limit Flag
# # COLUMN pl_orbeccen:    Eccentricity
# # COLUMN pl_orbeccenerr1: Eccentricity Upper Unc.
# # COLUMN pl_orbeccenerr2: Eccentricity Lower Unc.
# # COLUMN pl_orbeccenlim: Eccentricity Limit Flag
# # COLUMN pl_orbincl:     Inclination [deg]
# # COLUMN pl_orbinclerr1: Inclination Upper Unc. [deg]
# # COLUMN pl_orbinclerr2: Inclination Lower Unc. [deg]
# # COLUMN pl_orbincllim:  Inclination Limit Flag
# # COLUMN pl_bmassj:      Planet Mass or M*sin(i)[Jupiter mass]
# # COLUMN pl_bmassjerr1:  Planet Mass or M*sin(i)Upper Unc. [Jupiter mass]
# # COLUMN pl_bmassjerr2:  Planet Mass or M*sin(i)Lower Unc. [Jupiter mass]
# # COLUMN pl_bmassjlim:   Planet Mass or M*sin(i)Limit Flag
# # COLUMN pl_bmassprov:   Planet Mass or M*sin(i) Provenance
# # COLUMN pl_radj:        Planet Radius [Jupiter radii]
# # COLUMN pl_radjerr1:    Planet Radius Upper Unc. [Jupiter radii]
# # COLUMN pl_radjerr2:    Planet Radius Lower Unc. [Jupiter radii]
# # COLUMN pl_radjlim:     Planet Radius Limit Flag
# # COLUMN pl_dens:        Planet Density [g/cm**3]
# # COLUMN pl_denserr1:    Planet Density Upper Unc. [g/cm**3]
# # COLUMN pl_denserr2:    Planet Density Lower Unc. [g/cm**3]
# # COLUMN pl_denslim:     Planet Density Limit Flag
# # COLUMN pl_ttvflag:     TTV Flag
# # COLUMN pl_kepflag:     Kepler Field Flag
# # COLUMN pl_k2flag:      K2 Mission Flag
# # COLUMN pl_nnotes:      Number of Notes
# # COLUMN ra_str:         RA [sexagesimal]
# # COLUMN ra:             RA [sexagesimal]
# # COLUMN dec_str:        Dec [sexagesimal]
# # COLUMN dec:            Dec [sexagesimal]
# # COLUMN st_dist:        Distance [pc]
# # COLUMN st_disterr1:    Distance Upper Unc. [pc]
# # COLUMN st_disterr2:    Distance Lower Unc. [pc]
# # COLUMN st_distlim:     Distance Limit Flag
# # COLUMN st_optmag:      Optical Magnitude [mag]
# # COLUMN st_optmagerr:   Optical Magnitude Unc. [mag]
# # COLUMN st_optmaglim:   Optical Magnitude Limit Flag
# # COLUMN st_optmagblend: Optical Magnitude Blend Flag
# # COLUMN st_optband:     Optical Magnitude Band
# # COLUMN st_teff:        Effective Temperature [K]
# # COLUMN st_tefferr1:    Effective Temperature Upper Unc. [K]
# # COLUMN st_tefferr2:    Effective Temperature Lower Unc. [K]
# # COLUMN st_tefflim:     Effective Temperature Limit Flag
# # COLUMN st_teffblend:   Effective Temperature Blend Flag
# # COLUMN st_mass:        Stellar Mass [Solar mass]
# # COLUMN st_masserr1:    Stellar Mass Upper Unc. [Solar mass]
# # COLUMN st_masserr2:    Stellar Mass Lower Unc. [Solar mass]
# # COLUMN st_masslim:     Stellar Mass Limit Flag
# # COLUMN st_massblend:   Stellar Mass Blend Flag
# # COLUMN st_rad:         Stellar Radius [Solar radii]
# # COLUMN st_raderr1:     Stellar Radius Upper Unc. [Solar radii]
# # COLUMN st_raderr2:     Stellar Radius Lower Unc. [Solar radii]
# # COLUMN st_radlim:      Stellar Radius Limit Flag
# # COLUMN st_radblend:    Stellar Radius Blend Flag
# # COLUMN rowupdate:      Date of Last Update
#
# ```

# %% [markdown]
# ## My Exploratory Hypotheses
#
# Things I want plotted: eccentricity (eliptical shapes of orbit), effective temperature (avg. range of temperature affected by orbits), stellar radius (size of star), stellar mass (although corrolated to radius, it varies the type of star and therefore the properties of the exoplanet(s) involved), planet radius, discovery method (this helps us understand which method is the most useful in the search for planets) Orbital period, planet mass (is it jupiter or is it mercury) planet density (things that are related to the planet directly affect it)
#
# disclusion theories: # of planets in system (doesn't effect individual planet except perhaps in creation), orbit semi major axis (eliptical shape is the main changer in temps and seasons) inclination (i think that the orbit comparison between an exoplanet and objects in space doesn't affect the planet substantially, planes are somewhat subjective to the mean, and other objects with the exception of the sun (which isnt affected by the plane) don't affect the planet)
#
# IN COMPARISON TO EARTH (how many planets are unlike earth... how commmon is it for a planet to share multiple properties as earth putting it in the goldilocks zone)

# %%
data['pl_orbeccenerr1'].plot()

# %%
data['pl_orbeccenerr1'].hist()

# %% [markdown]
# Earth's orbit is like 0.0167 in eccentricity... so pretty much all of these planets have reallllllyyyyy extreme eccentricity levels in comparison, excluding the possibility for liquid water. If you have an extremely eccentric orbit that lasts like 14000 days (which is the case with one of these planets) you can have liquid water for a long time (Years one earth) but if there is also a large amount of time without acceptable temperatures, earth like life cannot evolve (without hibernation but there isn't any proof of that, and it would need to EVOLVE to hibernate, which would be unlikely)

# %%
data['pl_orbeccenerr2'].plot()

# %%
data['pl_bmassj'].plot()

# %%
data['pl_radj'].plot()

# %% [markdown]
# huge radius on one of the planets--- keeping in mind that one is JUPITER meaning that this anomoly planet is 7x the size of jupiter!

# %%
data['pl_orbsmax'].plot()

# %%
data['pl_orbper'].plot()

# %%
data['pl_dens'].plot()

# %%
data['pl_dens'].hist()

# %% [markdown]
# density of earth is small in comparison to the avg exoplanet in the milky way

# %%
data['st_mass'].plot()

# %%
data['st_mass'].hist()

# %%
data['st_mass'].plot()

# %%
data['st_mass'].hist()

# %% [markdown]
# How is temperature similar if eccentricity is completely different?! Is this affected by the star's mass?
